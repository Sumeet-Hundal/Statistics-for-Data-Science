# %%
import numpy as np
import pandas as pd
import seaborn as sns
import statsmodels.formula.api as sm
import matplotlib.pyplot as plt
from matplotlib.pyplot import scatter

# %%
xd1=pd.read_excel('ass4_linear_data.xlsx',sheet_name=0,names=['y','x'])
xd2=pd.read_excel('ass4_linear_data.xlsx',sheet_name=1,names=['y','x'])
xd3=pd.read_excel('ass4_linear_data.xlsx',sheet_name=2,names=['y','x'])
xd4=pd.read_excel('ass4_linear_data.xlsx',sheet_name=3,names=['y','x'])
xd5=pd.read_excel('ass4_linear_data.xlsx',sheet_name=4,names=['y','x'])
xd6=pd.read_excel('ass4_linear_data.xlsx',sheet_name=5,names=['y','x'])
xd4
# Out:
#                y       x
# 0   1.887192e+05  5.9947
# 1   7.107264e+03  3.9492
# 2   3.729064e+06  9.6353
# 3   5.691779e+02  0.4943
# 4   3.022130e+06  9.0811
# ..           ...     ...
# 95  1.132489e+06  8.4176
# 96  1.015551e+06  8.5450
# 97  2.653507e+04  5.4277
# 98  8.602001e+05  7.6067
# 99  2.847208e+06  9.2492
#
# [100 rows x 2 columns]

# %%
xd6.describe()
# Out:
#                 y           x
# count  101.000000  101.000000
# mean    39.178208    5.618743
# std     31.390864    4.268607
# min     -6.757358    0.111800
# 25%     19.890518    2.539300
# 50%     39.493906    5.446000
# 75%     56.813645    8.108500
# max    252.837897   35.783400

# %%
sns.pairplot(xd1)
xd1_c=xd1.corr(method = 'pearson')
xd1_c
# Out:
#           y         x
# y  1.000000  0.989468
# x  0.989468  1.000000

# %%
sns.pairplot(xd2)
xd2_c=xd2.corr(method = 'pearson')
xd2_c
# Out:
#           y         x
# y  1.000000  0.745168
# x  0.745168  1.000000

# %%
sns.pairplot(xd3)
xd3_c=xd3.corr(method = 'pearson')
xd3_c
# Out:
#           y         x
# y  1.000000  0.869031
# x  0.869031  1.000000

# %%
sns.pairplot(xd4)
xd4_c=xd4.corr(method = 'pearson')
xd4_c
# Out:
#           y         x
# y  1.000000  0.616155
# x  0.616155  1.000000

# %%
sns.pairplot(xd5)
xd5_c=xd5.corr(method = 'pearson')
xd5_c
# Out:
#           y         x
# y  1.000000  0.897892
# x  0.897892  1.000000

# %%
sns.pairplot(xd6)
xd6_c=xd6.corr(method = 'pearson')
xd6_c
# Out:
#           y         x
# y  1.000000  0.955578
# x  0.955578  1.000000

# %%
xdl3=pd.read_excel('ass4_linear_data.xlsx',sheet_name=2,names=['y','x'])
#xdl3=xdl3[['x','y']]
xdl3
# Out:
#                y      x
# 0    6428.915770  9.517
# 1    2640.000728  5.113
# 2   12858.599267  9.773
# 3    5491.450053  8.428
# 4    2838.820108  5.752
# ..           ...    ...
# 95   5242.604150  8.091
# 96    159.666278  1.325
# 97   2087.069663  4.446
# 98    206.866151  1.335
# 99   2773.134726  4.587
#
# [100 rows x 2 columns]

# %%
xdl3['x1'] = np.log(xdl3['x'])
xdl3['x2'] = (xdl3['x'])**(1/2)
xdl3['x3'] = (xdl3['x'])**(2)
xdl3['y1'] = np.log(xdl3['y'])
xdl3['y2'] = (xdl3['y'])**(1/2)
xdl3['y3'] = (xdl3['y'])**(2)
xdl3=xdl3[['x','x1','x2','x3','y','y1','y2','y3']]
xdl3
# Out:
#         x        x1        x2         x3             y        y1          y2  \
# 0   9.517  2.253080  3.084964  90.573289   6428.915770  8.768561   80.180520
# 1   5.113  1.631786  2.261194  26.142769   2640.000728  7.878534   51.380937
# 2   9.773  2.279623  3.126180  95.511529  12858.599267  9.461768  113.395764
# 3   8.428  2.131559  2.903102  71.031184   5491.450053  8.610948   74.104319
# 4   5.752  1.749548  2.398333  33.085504   2838.820108  7.951144   53.280579
# ..    ...       ...       ...        ...           ...       ...         ...
# 95  8.091  2.090752  2.844468  65.464281   5242.604150  8.564574   72.405830
# 96  1.325  0.281412  1.151086   1.755625    159.666278  5.073086   12.635912
# 97  4.446  1.492005  2.108554  19.766916   2087.069663  7.643516   45.684458
# 98  1.335  0.288931  1.155422   1.782225    206.866151  5.332072   14.382842
# 99  4.587  1.523226  2.141728  21.040569   2773.134726  7.927734   52.660561
#
#               y3
# 0   4.133096e+07
# ...

# %%
sns.pairplot(xdl3)
#xdl3_c=xdl3.corr(method = 'pearson')
#xdl3_c

# %%
xd2['x1']=xd2['x']**(1/2)
xd2['y1']=xd2['y']**(1/2)
xd2=xd2[['x','x1','y','y1']]
xd2
# Out:
#            x        x1          y        y1
# 0   4.299210  2.073454  28.045621  5.295812
# 1   4.528143  2.127943  39.148284  6.256859
# 2   3.284988  1.812454  17.361044  4.166659
# 3   5.709732  2.389505  18.413561  4.291103
# 4   3.242708  1.800752   7.857464  2.803117
# ..       ...       ...        ...       ...
# 95  5.103630  2.259122  25.808714  5.080228
# 96  1.769237  1.330127   9.549490  3.090225
# 97  7.474016  2.733865  36.904564  6.074913
# 98  5.459608  2.336580   4.750807  2.179635
# 99  6.455433  2.540754  15.409014  3.925432
#
# [100 rows x 4 columns]

# %%
sns.pairplot(xd2)

# %%
xd4['x1'] = np.log(xd4['x'])
xd4['x2'] = (xd4['x'])**(1/2)
xd4['x3'] = (xd4['x'])**(2)
xd4['y1'] = np.log(xd4['y'])
xd4['y2'] = (xd4['y'])**(1/2)
xd4['y3'] = (xd4['y'])**(2)
xd4=xd4[['x','x1','x2','x3','y','y1','y2','y3']]
xd4
# Out:
#          x        x1        x2         x3             y         y1  \
# 0   5.9947  1.790876  2.448408  35.936428  1.887192e+05  12.148015
# 1   3.9492  1.373513  1.987259  15.596181  7.107264e+03   8.868873
# 2   9.6353  2.265433  3.104078  92.839006  3.729064e+06  15.131668
# 3   0.4943 -0.704613  0.703065   0.244332  5.691779e+02   6.344193
# 4   9.0811  2.206195  3.013486  82.466377  3.022130e+06  14.921472
# ..     ...       ...       ...        ...           ...        ...
# 95  8.4176  2.130325  2.901310  70.855990  1.132489e+06  13.939929
# 96  8.5450  2.145346  2.923183  73.017025  1.015551e+06  13.830941
# 97  5.4277  1.691515  2.329742  29.459927  2.653507e+04  10.186223
# 98  7.6067  2.029029  2.758025  57.861885  8.602001e+05  13.664920
# 99  9.2492  2.224537  3.041250  85.547701  2.847208e+06  14.861849
#
#              y2            y3
# 0    434.418195  3.561492e+10
# 1     84.304593  5.051321e+07
# 2   1931.078398  1.390592e+13
# 3     23.857450  3.239635e+05
# ...

# %%
sns.pairplot(xd4)

# %%
sns.pairplot(xd4[['x','y1']])

# %%
m1 = sm.ols('y ~ x', data = xd1)
m1 = m1.fit()
m1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.979
# Model:                            OLS   Adj. R-squared:                  0.979
# Method:                 Least Squares   F-statistic:                     4579.
# Date:                Sun, 19 Apr 2020   Prob (F-statistic):           4.47e-84
# Time:                        21:57:22   Log-Likelihood:                -206.03
# No. Observations:                 100   AIC:                             416.1
# Df Residuals:                      98   BIC:                             421.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.2381      0.469      0.508      0.613      -0.693       1.169
# ...

# %%
intercept, slope = m1.params
xd1['y_est'] = intercept + slope * xd1.x

# %%
plt.plot(xd1.x, xd1.y, 'o', label = 'Observations')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Set 1')

# Draw estimates
plt.plot(xd1.x, xd1.y_est, 'r+', label='Estimates')

# Plot regression line
plt.plot(xd1.x, xd1.y_est, 'r-', label='Regression line')

# Plot errors
plt.vlines(xd1.x, xd1.y_est, xd1.y, linestyles='dashed', label = 'errors')

# Add legend
plt.legend()
plt.show()

# %% [markdown]
# ### [Set 1] The is no need to transfrom the data as can been seen from the plot with errors. The error from regression line is small. Also the r^sq= 97.9% which is very high and std error=0.074 is very low.

# %%
m2 = sm.ols('y ~ x', data = xd2)
m2 = m2.fit()
intercept, slope = m2.params
xd2['y_est'] = intercept + slope * xd2.x
m2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.555
# Model:                            OLS   Adj. R-squared:                  0.551
# Method:                 Least Squares   F-statistic:                     122.4
# Date:                Sun, 19 Apr 2020   Prob (F-statistic):           6.11e-19
# Time:                        22:27:54   Log-Likelihood:                -375.73
# No. Observations:                 100   AIC:                             755.5
# Df Residuals:                      98   BIC:                             760.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.0956      2.547      0.430      0.668      -3.958       6.149
# ...

# %%
plt.plot(xd2.x, xd2.y, 'o', label = 'Observations')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Set 2')

# Draw estimates
plt.plot(xd2.x, xd2.y_est, 'r+', label='Estimates')

# Plot regression line
#plt.plot(xd1.x, xd2.y_est, 'r-', label='Regression line')

# Plot errors
plt.vlines(xd2.x, xd2.y_est, xd2.y, linestyles='dashed', label = 'errors')

# Add legend
plt.legend()
plt.show()

# %% [markdown]
# ### [Set 2] The is no need to transfrom the data as the data is linear. The error from regression line is high but it is bother positive and negative, it still depicts the linear pattern. The standard error=0.432 is on the low side.

# %%
m3 = sm.ols('y ~ x', data = xd3)
m3 = m3.fit()
intercept, slope = m3.params
xd3['y_est'] = intercept + slope * xd3.x
m3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.755
# Model:                            OLS   Adj. R-squared:                  0.753
# Method:                 Least Squares   F-statistic:                     302.4
# Date:                Sun, 19 Apr 2020   Prob (F-statistic):           1.04e-31
# Time:                        22:33:25   Log-Likelihood:                -873.07
# No. Observations:                 100   AIC:                             1750.
# Df Residuals:                      98   BIC:                             1755.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -2636.1748    402.741     -6.546      0.000   -3435.400   -1836.949
# ...

# %%
plt.plot(xd3.x, xd3.y, 'o', label = 'Observations')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Set 3')

# Draw estimates
plt.plot(xd3.x, xd3.y_est, 'r+', label='Estimates')

# Plot regression line
plt.plot(xd3.x, xd3.y_est, 'r-', label='Regression line')

# Plot errors
plt.vlines(xd3.x, xd3.y_est, xd3.y, linestyles='dashed', label = 'errors')

# Add legend
plt.legend()
plt.show()

# %% [markdown]
# ### [Set 3] There is a need for transformation as the data is not linear. The r^sq=75% which is still good and the plot shows that regression does pass through much of the data but it can be improved with transformation.

# %%
ml3 = sm.ols(formula='xdl3.y1 ~ xdl3.x1', data = xdl3)
ml3 = ml3.fit()
ml3.params
intercept, slope = ml3.params
xdl3['y1_est'] = intercept + slope * xdl3.x1
# Out:
# C:\Users\sumee\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
plt.plot(xdl3.x1, xdl3.y1, 'o', label = 'Observations')
plt.xlabel('x1')
plt.ylabel('y1')
plt.title('Set 3 Log(x&y)')

# Draw estimates
plt.plot(xdl3.x1, xdl3.y1_est, 'r+', label='Estimates')

# Plot regression line
plt.plot(xdl3.x1, xdl3.y1_est, 'r-', label='Regression line')

# Plot errors
plt.vlines(xdl3.x1, xdl3.y1_est, xdl3.y1, linestyles='dashed', label = 'errors')

# Add legend
plt.legend()
plt.show()

# %%
xdl3[['x1','y1']].loc[(xdl3['x1']>1.3) & (xdl3['y1']<6.5) ]
xdl31=xdl3.drop(67)

# %%
ml31 = sm.ols(formula='xdl31.y1 ~ xdl31.x1', data = xdl31)
ml31 = ml31.fit()
ml31.params
intercept, slope = ml31.params
xdl31['y1_est'] = intercept + slope * xdl31.x1

# %%
ml3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                xdl3.y1   R-squared:                       0.902
# Model:                            OLS   Adj. R-squared:                  0.901
# Method:                 Least Squares   F-statistic:                     904.8
# Date:                Sun, 19 Apr 2020   Prob (F-statistic):           2.74e-51
# Time:                        21:46:00   Log-Likelihood:                -40.302
# No. Observations:                 100   AIC:                             84.60
# Df Residuals:                      98   BIC:                             89.81
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      4.3508      0.120     36.221      0.000       4.112       4.589
# ...

# %%
ml31.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               xdl31.y1   R-squared:                       0.919
# Model:                            OLS   Adj. R-squared:                  0.918
# Method:                 Least Squares   F-statistic:                     1100.
# Date:                Sun, 19 Apr 2020   Prob (F-statistic):           9.95e-55
# Time:                        21:46:16   Log-Likelihood:                -30.338
# No. Observations:                  99   AIC:                             64.68
# Df Residuals:                      97   BIC:                             69.87
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      4.3622      0.109     39.984      0.000       4.146       4.579
# ...

# %% [markdown]
# ### [Set 3] Based on the multiple attempts to transform the data, best results came fro logarithm for both x and y values. The r^sq=91.9% is much better than the original 75% and the standard error is low as well. Removing the one outlier did not make much difference as he r^sq value increased only by 1.7%. Overall the regression line fits much better after transformation. The intercept went from very high engative value to 4 after transformation which is justified as the original data follow a exponential path. The slope also reduced a lot in the transformed data from the original data.

# %%
plt.plot(xdl31.x1, xdl31.y1, 'o', label = 'Observations')
plt.xlabel('x1')
plt.ylabel('y1')
plt.title('Set 3 Log(x&y)')

# Draw estimates
plt.plot(xdl31.x1, xdl31.y1_est, 'r+', label='Estimates')

# Plot regression line
plt.plot(xdl31.x1, xdl31.y1_est, 'r-', label='Regression line')

# Plot errors
plt.vlines(xdl31.x1, xdl31.y1_est, xdl31.y1, linestyles='dashed', label = 'errors')

# Add legend
plt.legend()
plt.show()

# %%
m4 = (sm.ols('y ~ x', data = xd4)).fit()
m4.params
intercept, slope = m4.params
xd4['y_est'] = intercept + slope * xd4.x
m4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.380
# Model:                            OLS   Adj. R-squared:                  0.373
# Method:                 Least Squares   F-statistic:                     59.97
# Date:                Sun, 19 Apr 2020   Prob (F-statistic):           8.87e-12
# Time:                        21:54:05   Log-Likelihood:                -1526.2
# No. Observations:                 100   AIC:                             3056.
# Df Residuals:                      98   BIC:                             3062.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -7.535e+05    2.1e+05     -3.585      0.001   -1.17e+06   -3.36e+05
# ...

# %%
plt.plot(xd4.x, xd4.y, 'o', label = 'Observations')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Set 4')

# Draw estimates
plt.plot(xd4.x, xd4.y_est, 'r+', label='Estimates')

# Plot regression line
plt.plot(xd4.x, xd4.y_est, 'r-', label='Regression line')

# Plot errors
plt.vlines(xd4.x, xd4.y_est, xd4.y, linestyles='dashed', label = 'errors')

# Add legend
plt.legend()
plt.show()

# %% [markdown]
# ### [Set 4] There is a need for transformation as the data is not linear at all. The r^sq=38% is very low and the errors are not centered around which can be seen from the plot above.

# %%
ml4 = (sm.ols(formula='xd4.y1 ~ xd4.x', data = xd4)).fit()
intercept, slope = ml4.params
xd4['y1_est'] = intercept + slope * xd4.x

# %%
ml4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 xd4.y1   R-squared:                       0.983
# Model:                            OLS   Adj. R-squared:                  0.983
# Method:                 Least Squares   F-statistic:                     5765.
# Date:                Sun, 19 Apr 2020   Prob (F-statistic):           6.91e-89
# Time:                        21:53:21   Log-Likelihood:                -46.034
# No. Observations:                 100   AIC:                             96.07
# Df Residuals:                      98   BIC:                             101.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      5.6647      0.078     72.264      0.000       5.509       5.820
# ...

# %%
plt.plot(xd4.x, xd4.y1, 'o', label = 'Observations')
plt.xlabel('x')
plt.ylabel('y1')
plt.title('Set 4 Log(y)')

# Draw estimates
plt.plot(xd4.x, xd4.y1_est, 'r+', label='Estimates')

# Plot regression line
plt.plot(xd4.x, xd4.y1_est, 'r-', label='Regression line')

# Plot errors
plt.vlines(xd4.x, xd4.y1_est, xd4.y1, linestyles='dashed', label = 'errors')

# Add legend
plt.legend()
plt.show()

# %% [markdown]
# ### [Set 4] Based on the multiple attempts to transform the data, best results came from logarithm y values and original x values. The r^sq=98.3% is very high and standard error is very low at 0.13. There are no outliers. Overall the regression line fits much much better after transformation. The Intercept went from high negative calue to a possitive value of 5 after transformation. The slope also went from 200k to very low value of less than 1.

# %%
m5 = (sm.ols('y ~ x', data = xd5)).fit()
m5.params
intercept, slope = m5.params
xd5['y_est'] = intercept + slope * xd5.x
m5.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.806
# Model:                            OLS   Adj. R-squared:                  0.804
# Method:                 Least Squares   F-statistic:                     411.9
# Date:                Sun, 19 Apr 2020   Prob (F-statistic):           4.70e-37
# Time:                        21:13:38   Log-Likelihood:                -334.42
# No. Observations:                 101   AIC:                             672.8
# Df Residuals:                      99   BIC:                             678.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.9213      1.346      0.685      0.495      -1.749       3.591
# ...

# %%
xd51=xd5.drop(100)

# %%
m51 = (sm.ols('y ~ x', data = xd51)).fit()
m51.params
intercept, slope = m51.params
xd51['y_est'] = intercept + slope * xd51.x
m51.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.906
# Model:                            OLS   Adj. R-squared:                  0.905
# Method:                 Least Squares   F-statistic:                     945.8
# Date:                Sun, 19 Apr 2020   Prob (F-statistic):           3.84e-52
# Time:                        21:08:50   Log-Likelihood:                -294.13
# No. Observations:                 100   AIC:                             592.3
# Df Residuals:                      98   BIC:                             597.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0993      0.935     -0.106      0.916      -1.954       1.756
# ...

# %%
plt.plot(xd5.x, xd5.y, 'o', label = 'Observations')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Set 5')

# Draw estimates
plt.plot(xd5.x, xd5.y_est, 'r+', label='Estimates')

# Plot regression line
plt.plot(xd5.x, xd5.y_est, 'r-', label='Regression line')

# Plot errors
plt.vlines(xd5.x, xd5.y_est, xd5.y, linestyles='dashed', label = 'errors')

# Add legend
plt.legend()
plt.show()

# %%
m51.params
# Out:
# Intercept   -0.099290
# x            5.070538
# dtype: float64

# %% [markdown]
# ### [Set 5 Outlier ] Dropping the one outlier from data set5, resulted in the intercept changing from being positive with outlier and negative without outlier. Also the slope increased after dropping the oulier from 4.77 to 5.07. The r squared value had a huge influence as with the outlier the r^sq=80.6% and without outlier r^sq=90.6% which is a 10% difference.

# %%
plt.plot(xd51.x, xd51.y, 'o', label = 'Observations')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Set 5')

# Draw estimates
plt.plot(xd51.x, xd51.y_est, 'r+', label='Estimates')

# Plot regression line
plt.plot(xd51.x, xd51.y_est, 'r-', label='Regression line')

# Plot errors
plt.vlines(xd51.x, xd51.y_est, xd51.y, linestyles='dashed', label = 'errors')

# Add legend
plt.legend()
plt.show()

# %%
m6 = (sm.ols('y ~ x', data = xd6)).fit()
intercept, slope = m6.params
xd6['y_est'] = intercept + slope * xd6.x
m6.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.913
# Model:                            OLS   Adj. R-squared:                  0.912
# Method:                 Least Squares   F-statistic:                     1041.
# Date:                Sun, 19 Apr 2020   Prob (F-statistic):           2.49e-54
# Time:                        23:03:16   Log-Likelihood:                -367.52
# No. Observations:                 101   AIC:                             739.0
# Df Residuals:                      99   BIC:                             744.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.3059      1.534     -0.199      0.842      -3.350       2.739
# ...

# %%
plt.plot(xd6.x, xd6.y, 'o', label = 'Observations')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Set 6')

# Draw estimates
plt.plot(xd6.x, xd6.y_est, 'r+', label='Estimates')

# Plot regression line
plt.plot(xd6.x, xd6.y_est, 'r-', label='Regression line')

# Plot errors
plt.vlines(xd6.x, xd6.y_est, xd6.y, linestyles='dashed', label = 'errors')

# Add legend
plt.legend()
plt.show()

# %% [markdown]
# ### [Set 6] The is no need to transfrom the data as can been seen from the plot with errors. The error from regression line is small. Also the r^sq= 91.3% which is very high and error of values are low. There are no outliers, the last y value looks like an outlier but the liner regression it cane be seen that it is not an outlier.
